# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import process_rolls as pr
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from statistics import mean, mode

# %%
sns.set_context("talk")

# %%
with open(pr.ROLLS_FILE) as f:
    data = f.readlines()

# %%
user_rolls = pr.get_rolls_by_user(data)
df = pr.transpose_to_rolls_dataframe(user_rolls)

# %%
pr.plot_rolls_by_user(df)

# %%
successes_df = pr.apply_function_for_users(user_rolls, "% successes", pr.count_successes)

# %%
pr.plot_bar_quantity_by_user(successes_df, "% successes")

# %%
average_df = pr.apply_function_for_users(user_rolls, "average roll", mean)
plt.axvline(x=mean(range(pr.MIN_DIE, pr.MAX_DIE + 1)), color="black", linestyle="dashed")
pr.plot_scatter_quantity_by_user(average_df, "average roll")

# %%
mode_df = pr.apply_function_for_users(user_rolls, "most common roll", mode)
pr.plot_scatter_quantity_by_user(mode_df, "most common roll")
